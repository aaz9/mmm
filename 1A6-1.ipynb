# %%
import pandas as pd
import numpy as np
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# %%
d = loadtxt("C:/pima-indians-diabetes.csv", delimiter = ',')

# %%
print(d)
# Out:
# [[  6.    148.     72.    ...   0.627  50.      1.   ]
#  [  1.     85.     66.    ...   0.351  31.      0.   ]
#  [  8.    183.     64.    ...   0.672  32.      1.   ]
#  ...
#  [  5.    121.     72.    ...   0.245  30.      0.   ]
#  [  1.    126.     60.    ...   0.349  47.      1.   ]
#  [  1.     93.     70.    ...   0.315  23.      0.   ]]

# %%
print(d.ndim)
# Out:
# 2

# %%
print(d.shape)
# Out:
# (768, 9)

# %%
x = d[:, 0:8]
y = d[:, 8]

# %%
model = Sequential()

# %%
model.add(Dense(12, input_dim= 8, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.summary
# Out:
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x000002187C47C3A0>>

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x, y, epochs = 50, batch_size=10)
# Out:
# Epoch 1/50
# 77/77 [==============================] - 1s 2ms/step - loss: 4.6084 - accuracy: 0.6224
# Epoch 2/50
# 77/77 [==============================] - 0s 2ms/step - loss: 0.9455 - accuracy: 0.5078
# Epoch 3/50
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7668 - accuracy: 0.5599
# Epoch 4/50
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7117 - accuracy: 0.5924
# Epoch 5/50
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.6016
# Epoch 6/50
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6845 - accuracy: 0.6068
# Epoch 7/50
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6595 - accuracy: 0.6263
# Epoch 8/50
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6380 - accuracy: 0.6497
# Epoch 9/50
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6445 - accuracy: 0.6693
# Epoch 10/50
# ...

# %%
scores = model.evaluate(x, y)

print("%s : %0.2f%%" % (model.metrics_names[0], scores[0] * 100))
print("%s : %0.2f%%" % (model.metrics_names[1], scores[1] * 100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5321 - accuracy: 0.7448
# loss : 53.21%
# accuracy : 74.48%

# %%
prediction = model.predict(x)


rounded = [round(x[0]) for x in prediction]
# Out:
# 24/24 [==============================] - 0s 2ms/step

# %%
for i in range(0, d.shape[0]):
  print("%s => %d ( expected %d)" % (x[i].tolist(), prediction[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 0 ( expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 ( expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 0 ( expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 ( expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 0 ( expected 1)
# [5.0, 116.0, 74.0, 0.0, 0.0, 25.6, 0.201, 30.0] => 0 ( expected 0)
# [3.0, 78.0, 50.0, 32.0, 88.0, 31.0, 0.248, 26.0] => 0 ( expected 1)
# [10.0, 115.0, 0.0, 0.0, 0.0, 35.3, 0.134, 29.0] => 0 ( expected 0)
# [2.0, 197.0, 70.0, 45.0, 543.0, 30.5, 0.158, 53.0] => 0 ( expected 1)
# [8.0, 125.0, 96.0, 0.0, 0.0, 0.0, 0.232, 54.0] => 0 ( expected 1)
# [4.0, 110.0, 92.0, 0.0, 0.0, 37.6, 0.191, 30.0] => 0 ( expected 0)
# [10.0, 168.0, 74.0, 0.0, 0.0, 38.0, 0.537, 34.0] => 0 ( expected 1)
# [10.0, 139.0, 80.0, 0.0, 0.0, 27.1, 1.441, 57.0] => 0 ( expected 0)
# [1.0, 189.0, 60.0, 23.0, 846.0, 30.1, 0.398, 59.0] => 0 ( expected 1)
# ...

# %%
# !pip install ann_visualizer

# %%
# !pip install graphviz

# %%
from ann_visualizer.visualize import ann_viz
from graphviz import Source

# %%
ann_viz(model, view=True, filename = 'a.gv', title = "aaaaa")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      80     else:
# ---> 81         proc = subprocess.run(cmd, **kwargs)
#      82 except OSError as e:
#
# File ~\anaconda3\lib\subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     501     kwargs['stderr'] = PIPE
# --> 503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
#
# File ~\anaconda3\lib\subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     968             self.stderr = io.TextIOWrapper(self.stderr,
# ...

# %%
a = Source.from_file('a.gv')

# %%
a
